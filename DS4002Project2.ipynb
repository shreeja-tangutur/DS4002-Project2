# %% [markdown]
# <a href="https://colab.research.google.com/github/shreeja-tangutur/DS4002-Project2/blob/main/DS4002Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load data
df = pd.read_csv('/content/Air_Quality.csv')

# Basic overview
print("Shape of dataset:", df.shape)
print("\nColumn names:")
print(df.columns)

print("\nFirst 5 rows:")
display(df.head())

print("\nData types:")
print(df.dtypes)
# Out:
# Shape of dataset: (18862, 12)
#
# Column names:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')
#
# First 5 rows:
#    Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                     Geo Place Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time Period  Start_Date  Data Value  Message
# 0       Winter 2014-15  12/01/2014       23.97      NaN
# 1       Winter 2014-15  12/01/2014       27.42      NaN
# 2  Annual Average 2017  01/01/2017       12.55      NaN
# 3       Winter 2015-16  12/01/2015       22.63      NaN
# 4          Summer 2016  06/01/2016       14.00      NaN
# Data types:
# Unique ID           int64
# Indicator ID        int64
# Name               object
# Measure            object
# Measure Info       object
# Geo Type Name      object
# Geo Join ID         int64
# Geo Place Name     object
# Time Period        object
# Start_Date         object
# Data Value        float64
# Message           float64
# dtype: object

# %%
# Convert to datetime
df['Date'] = pd.to_datetime(df['Start_Date'])

# Sort ascending
df = df.sort_values(by='Date')

# Reset index
df = df.reset_index(drop=True)

print("Sorted by Date (Ascending):")
display(df.head())
# Out:
# Sorted by Date (Ascending):
#    Unique ID  Indicator ID                                              Name  \
# 0     131263           657   Asthma emergency department visits due to PM2.5
# 1     130380           639                               Deaths due to PM2.5
# 2     130390           639                               Deaths due to PM2.5
# 3     154485           645            Annual vehicle miles traveled (trucks)
# 4     131062           653  Asthma emergency departments visits due to Ozone
#
#                                 Measure          Measure Info Geo Type Name  \
# 0       Estimated annual rate (age 18+)    per 100,000 adults       Borough
# 1       Estimated annual rate (age 30+)    per 100,000 adults         UHF42
# 2       Estimated annual rate (age 30+)    per 100,000 adults         UHF42
# 3                         Million miles       per square mile            CD
# 4  Estimated annual rate (under age 18)  per 100,000 children         UHF42
#
#    Geo Join ID                Geo Place Name Time Period  Start_Date  \
# 0            2                      Brooklyn   2005-2007  01/01/2005
# 1          308      Greenwich Village - SoHo   2005-2007  01/01/2005
# 2          408                       Jamaica   2005-2007  01/01/2005
# 3          402  Woodside and Sunnyside (CD2)        2005  01/01/2005
# 4          408                       Jamaica   2005-2007  01/01/2005
#
#    Data Value  Message       Date
# 0   55.500000      NaN 2005-01-01
# 1   45.400000      NaN 2005-01-01
# 2   58.200000      NaN 2005-01-01
# 3    5.029655      NaN 2005-01-01
# 4  103.900000      NaN 2005-01-01

# %%
print("Earliest date:", df['Date'].min())
print("Latest date:", df['Date'].max())
print("Number of unique timestamps:", df['Date'].nunique())
# Out:
# Earliest date: 2005-01-01 00:00:00
# Latest date: 2023-06-01 00:00:00
# Number of unique timestamps: 46

# %%
print("Unique Areas:")
areas = df['Geo Place Name'].unique()
print(areas)

print("\nNumber of Areas:", len(areas))
# Out:
# Unique Areas:
# ['Brooklyn' 'Greenwich Village - SoHo' 'Jamaica'
#  'Woodside and Sunnyside (CD2)' 'Sheepshead Bay (CD15)'
#  'Hunts Point - Mott Haven' 'Queens Village (CD13)'
#  'High Bridge - Morrisania' 'Gramercy Park - Murray Hill'
#  'Canarsie - Flatlands' 'East Flatbush - Flatbush' 'Flushing - Clearview'
#  'Willowbrook' 'Sunset Park' 'Bronx' 'Coney Island - Sheepshead Bay'
#  'Williamsburg - Bushwick' 'Chelsea - Clinton' 'Upper West Side'
#  'Pelham - Throgs Neck' 'Staten Island' 'Bayside - Little Neck'
#  'Rockaways' 'Northeast Bronx' 'Upper East Side' 'Crotona -Tremont'
#  'Bedford Stuyvesant - Crown Heights' 'Ridgewood - Forest Hills'
#  'Downtown - Heights - Slope' 'Central Harlem - Morningside Heights'
#  'Kingsbridge - Riverdale' 'Long Island City - Astoria'
#  'Washington Heights' 'Manhattan' 'Fordham - Bronx Pk' 'Borough Park'
#  'Throgs Neck and Co-op City (CD10)' 'Greenpoint' 'Port Richmond'
#  'East New York' 'Midtown (CD5)' 'Ridgewood and Maspeth (CD5)'
#  'South Beach - Tottenville' 'Bensonhurst - Bay Ridge' 'Southwest Queens'
#  'East Harlem' 'Southeast Queens' 'West Queens'
#  'Bayside and Little Neck (CD11)' 'Upper West Side (CD7)'
#  'South Crown Heights and Lefferts Gardens (CD9)'
#  'Morningside Heights and Hamilton Heights (CD9)'
#  'Kew Gardens and Woodhaven (CD9)' 'Stapleton - St. George'
#  'Lower Manhattan' 'Union Square - Lower East Side' 'New York City'
#  'South Beach and Willowbrook (CD2)'
#  'Fort Greene and Brooklyn Heights (CD2)' 'Hunts Point and Longwood (CD2)'
#  'Queens' 'St. George and Stapleton (CD1)'
#  'Greenpoint and Williamsburg (CD1)' 'Morrisania and Crotona (CD3)'
#  'Elmhurst and Corona (CD4)' 'Tottenville and Great Kills (CD3)'
#  'Greenwich Village and Soho (CD2)' 'Fresh Meadows'
#  'Williamsbridge and Baychester (CD12)' 'Flatbush and Midwood (CD14)'
#  'Rockaway and Broad Channel (CD14)' 'Sunset Park (CD7)'
#  'Upper East Side (CD8)' 'Jamaica and Hollis (CD12)'
#  'Rego Park and Forest Hills (CD6)' 'Central Harlem (CD10)'
#  'Washington Heights and Inwood (CD12)' 'Belmont and East Tremont (CD6)'
#  'Riverdale and Fieldston (CD8)' 'Stuyvesant Town and Turtle Bay (CD6)'
#  'Brownsville (CD16)' 'Fordham and University Heights (CD5)'
#  'Crown Heights and Prospect Heights (CD8)'
#  'South Ozone Park and Howard Beach (CD10)' 'Bushwick (CD4)'
#  'Highbridge and Concourse (CD4)' 'East Flatbush (CD17)'
#  'Flatlands and Canarsie (CD18)' 'Bensonhurst (CD11)'
#  'Long Island City and Astoria (CD1)' 'Financial District (CD1)'
#  'Mott Haven and Melrose (CD1)' 'Lower East Side and Chinatown (CD3)'
#  'Bedford Stuyvesant (CD3)' 'Coney Island (CD13)' 'Jackson Heights (CD3)'
#  'Flushing and Whitestone (CD7)' 'Kingsbridge Heights and Bedford (CD7)'
#  'Bay Ridge and Dyker Heights (CD10)' 'Borough Park (CD12)'
#  'East New York and Starrett City (CD5)' 'East Harlem (CD11)'
#  'Parkchester and Soundview (CD9)' 'Morris Park and Bronxdale (CD11)'
#  'Hillcrest and Fresh Meadows (CD8)'
#  'Park Slope and Carroll Gardens (CD6)' 'Clinton and Chelsea (CD4)'
#  'Bayside Little Neck-Fresh Meadows' 'Upper East Side-Gramercy'
#  'Chelsea-Village' 'Northern SI' 'Southern SI' 'South Bronx'
#  'Union Square-Lower Manhattan']
#
# Number of Areas: 114

# %%
avg_area_pollutant = (
    df.groupby(['Geo Place Name', 'Name'])['Data Value']
      .mean()
      .reset_index()
)

print("Average Air Quality per Area and Pollutant:")
display(avg_area_pollutant)
# Out:
# Average Air Quality per Area and Pollutant:
#                           Geo Place Name  \
# 0     Bay Ridge and Dyker Heights (CD10)
# 1     Bay Ridge and Dyker Heights (CD10)
# 2     Bay Ridge and Dyker Heights (CD10)
# 3     Bay Ridge and Dyker Heights (CD10)
# 4     Bay Ridge and Dyker Heights (CD10)
# ...                                  ...
# 1352        Woodside and Sunnyside (CD2)
# 1353        Woodside and Sunnyside (CD2)
# 1354        Woodside and Sunnyside (CD2)
# 1355        Woodside and Sunnyside (CD2)
# 1356        Woodside and Sunnyside (CD2)
#
#                                         Name  Data Value
# 0              Annual vehicle miles traveled   70.910190
# 1       Annual vehicle miles traveled (cars)   65.642592
# 2     Annual vehicle miles traveled (trucks)    3.983465
# 3                    Fine particles (PM 2.5)    8.530959
# 4                     Nitrogen dioxide (NO2)   19.247917
# ...                                      ...         ...
# 1352                 Fine particles (PM 2.5)    9.980413
# 1353                  Nitrogen dioxide (NO2)   21.983543
# 1354            Outdoor Air Toxics - Benzene    1.834309
# 1355       Outdoor Air Toxics - Formaldehyde    2.400000
# 1356                              Ozone (O3)   31.041822
#
# [1357 rows x 3 columns]

# %%
area_avg = (
    avg_area_pollutant
    .groupby('Geo Place Name')['Data Value']
    .mean()
    .reset_index()
)



area_avg_sorted = area_avg.sort_values(by='Data Value', ascending=False)



top3 = area_avg_sorted.head(3)
print("Top 3 Highest Average Air Quality Values:")
display(top3)
bottom3 = area_avg_sorted.tail(3)
print("Top 3 Lowest Average Air Quality Values:")
display(bottom3)
# Out:
# Top 3 Highest Average Air Quality Values:
#                           Geo Place Name  Data Value
# 95  Stuyvesant Town and Turtle Bay (CD6)   53.621603
# 28                           East Harlem   51.676142
# 42           Gramercy Park - Murray Hill   50.751755
# Top 3 Lowest Average Air Quality Values:
#                        Geo Place Name  Data Value
# 84          South Beach - Tottenville   11.519418
# 81  Rockaway and Broad Channel (CD14)   11.222026
# 99  Tottenville and Great Kills (CD3)   10.288473

# %%
duplicate_area_date = (
    df.groupby(['Geo Place Name', 'Date'])
      .size()
      .reset_index(name='count')
)

# Keep only cases where count > 1
duplicates = duplicate_area_date[duplicate_area_date['count'] > 1]

print("Area-Date combinations with multiple entries:")
display(duplicates.head())

print("Total such cases:", len(duplicates))
# Out:
# Area-Date combinations with multiple entries:
#                        Geo Place Name       Date  count
# 0  Bay Ridge and Dyker Heights (CD10) 2005-01-01      3
# 1  Bay Ridge and Dyker Heights (CD10) 2008-12-01      4
# 2  Bay Ridge and Dyker Heights (CD10) 2009-06-01      3
# 3  Bay Ridge and Dyker Heights (CD10) 2009-12-01      4
# 4  Bay Ridge and Dyker Heights (CD10) 2010-01-01      3
# Total such cases: 4959

# %%
pm25_df = df[df['Name'] == 'Fine particles (PM 2.5)'].copy()

print("Filtered dataset shape:", pm25_df.shape)
display(pm25_df.head())
# Out:
# Filtered dataset shape: (6345, 13)
#      Unique ID  Indicator ID                     Name Measure Measure Info  \
# 897     168434           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 898     177178           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 899     174115           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 901     170179           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 902     173109           365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#     Geo Type Name  Geo Join ID                      Geo Place Name  \
# 897            CD          317                East Flatbush (CD17)
# 898         UHF42          502              Stapleton - St. George
# 899         UHF34          203  Bedford Stuyvesant - Crown Heights
# 901            CD          204      Highbridge and Concourse (CD4)
# 902         UHF34          402                         West Queens
#
#              Time Period  Start_Date  Data Value  Message       Date
# 897       Winter 2008-09  12/01/2008       13.25      NaN 2008-12-01
# 898       Winter 2008-09  12/01/2008       11.46      NaN 2008-12-01
# 899  Annual Average 2009  12/01/2008       10.75      NaN 2008-12-01
# 901  Annual Average 2009  12/01/2008       11.96      NaN 2008-12-01
# 902       Winter 2008-09  12/01/2008       13.50      NaN 2008-12-01

# %%
pm25_df.to_csv('PM25_only.csv', index=False)

print("CSV saved as PM25_only.csv")
# Out:
# CSV saved as PM25_only.csv

# %%
cd_df = df[df['Geo Type Name'] == 'CD'].copy()

print("Filtered dataset shape:", cd_df.shape)
display(cd_df.head())
# Out:
# Filtered dataset shape: (6844, 13)
#     Unique ID  Indicator ID                                    Name  \
# 3      154485           645  Annual vehicle miles traveled (trucks)
# 6      154598           643           Annual vehicle miles traveled
# 8      154614           643           Annual vehicle miles traveled
# 47     154463           645  Annual vehicle miles traveled (trucks)
# 67     154446           645  Annual vehicle miles traveled (trucks)
#
#           Measure     Measure Info Geo Type Name  Geo Join ID  \
# 3   Million miles  per square mile            CD          402
# 6   Million miles  per square mile            CD          315
# 8   Million miles  per square mile            CD          413
# 47  Million miles  per square mile            CD          210
# 67  Million miles  per square mile            CD          105
#
#                        Geo Place Name Time Period  Start_Date  Data Value  \
# 3        Woodside and Sunnyside (CD2)        2005  01/01/2005    5.029655
# 6               Sheepshead Bay (CD15)        2005  01/01/2005   42.865708
# 8               Queens Village (CD13)        2005  01/01/2005   59.429215
# 47  Throgs Neck and Co-op City (CD10)        2005  01/01/2005    4.939819
# 67                      Midtown (CD5)        2005  01/01/2005   10.903427
#
#     Message       Date
# 3       NaN 2005-01-01
# 6       NaN 2005-01-01
# 8       NaN 2005-01-01
# 47      NaN 2005-01-01
# 67      NaN 2005-01-01

# %%
print(cd_df['Geo Type Name'].unique())

num_unique_cds = cd_df['Geo Place Name'].nunique()

print("Number of unique CDs:", num_unique_cds)
# Out:
# ['CD']
# Number of unique CDs: 59

# %%
cd_df.to_csv('NYC_CD_only.csv', index=False)

print("CSV saved as NYC_CD_only.csv")
# Out:
# CSV saved as NYC_CD_only.csv

# %%
cd_pm25_df = df[
    (df['Geo Type Name'] == 'CD') &
    (df['Name'] == 'Fine particles (PM 2.5)')
].copy()

print("Filtered shape:", cd_pm25_df.shape)
display(cd_pm25_df.head())
# Out:
# Filtered shape: (2655, 13)
#      Unique ID  Indicator ID                     Name Measure Measure Info  \
# 897     168434           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 901     170179           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 905     168450           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 907     168451           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 908     168395           365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#     Geo Type Name  Geo Join ID                     Geo Place Name  \
# 897            CD          317               East Flatbush (CD17)
# 901            CD          204     Highbridge and Concourse (CD4)
# 905            CD          501     St. George and Stapleton (CD1)
# 907            CD          502  South Beach and Willowbrook (CD2)
# 908            CD          102   Greenwich Village and Soho (CD2)
#
#              Time Period  Start_Date  Data Value  Message       Date
# 897       Winter 2008-09  12/01/2008       13.25      NaN 2008-12-01
# 901  Annual Average 2009  12/01/2008       11.96      NaN 2008-12-01
# 905       Winter 2008-09  12/01/2008       12.09      NaN 2008-12-01
# 907       Winter 2008-09  12/01/2008       11.77      NaN 2008-12-01
# 908       Winter 2008-09  12/01/2008       15.21      NaN 2008-12-01

# %%
cd_pm25_df.to_csv('NYC_CD_PM25_only.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


overall_trend = (
    cd_pm25_df
    .groupby('Date')['Data Value']
    .mean()
    .reset_index()
)

plt.figure(figsize=(12,5))
plt.plot(overall_trend['Date'], overall_trend['Data Value'])
plt.title("Average PM2.5 Across All NYC Community Districts Over Time")
plt.xlabel("Year")
plt.ylabel("PM2.5 (mcg/m3)")
plt.show()

# %%
cd_avg = (
    cd_pm25_df
    .groupby('Geo Place Name')['Data Value']
    .mean()
    .sort_values(ascending=False)
)

top5 = cd_avg.head(5)

plt.figure(figsize=(8,5))
top5.plot(kind='bar')
plt.title("Top 5 Highest Average PM2.5 CDs")
plt.ylabel("Average PM2.5")
plt.show()
